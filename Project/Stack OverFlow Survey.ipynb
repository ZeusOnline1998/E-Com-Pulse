# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv')
schema_df = pd.read_csv('survey_results_schema.csv', index_col='Column')

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df.shape
# Out:
# (88883, 85)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df.head(5)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.tail(10)
# Out:
#        Respondent MainBranch Hobbyist  \
# 88873       88062        NaN       No
# 88874       88076        NaN       No
# 88875       88182        NaN      Yes
# 88876       88212        NaN       No
# 88877       88282        NaN      Yes
# 88878       88377        NaN      Yes
# 88879       88601        NaN       No
# 88880       88802        NaN       No
# 88881       88816        NaN       No
# 88882       88863        NaN      Yes
#
#                                              OpenSourcer  \
# 88873                                              Never
# 88874                                              Never
# 88875                         Once a month or more often
# 88876                            Less than once per year
# 88877                         Once a month or more often
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# ...

# %%
df.tail(5).to_dict('list')
# Out:
# {'Respondent': [88377, 88601, 88802, 88816, 88863],
#  'MainBranch': [nan, nan, nan, nan, nan],
#  'Hobbyist': ['Yes', 'No', 'No', 'No', 'Yes'],
#  'OpenSourcer': ['Less than once a month but more than once per year',
#   'Never',
#   'Never',
#   'Never',
#   'Less than once per year'],
#  'OpenSource': ['The quality of OSS and closed source software is about the same',
#   'The quality of OSS and closed source software is about the same',
#   nan,
#   'OSS is, on average, of HIGHER quality than proprietary / closed source software',
#   'OSS is, on average, of HIGHER quality than proprietary / closed source software'],
#  'Employment': ['Not employed, and not looking for work',
#   nan,
#   'Employed full-time',
#   'Independent contractor, freelancer, or self-employed',
#   'Not employed, and not looking for work'],
#  'Country': ['Canada', nan, nan, nan, 'Spain'],
#  'Student': ['No', nan, nan, nan, 'Yes, full-time'],
#  'EdLevel': ['Primary/elementary school',
#   nan,
#   nan,
# ...

# %% [markdown]
# # df.columns - Returns Index of the dataframe

# %% [markdown]
# # df.loc - Returns row of records taking index as whole numbers

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %% [markdown]
# # We can retreive multiple rows by passing list of index

# %%
df.loc[[0,1,2]]
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
# 2                    Never  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
# 2                      Employed full-time                Thailand
#
#           Student                                            EdLevel  \
# ...

# %% [markdown]
# # d.iloc - It returns row/s of records while taking integer index as well

# %%
df.iloc[-1]
# Out:
# Respondent                                                            88863
# MainBranch                                                              NaN
# Hobbyist                                                                Yes
# OpenSourcer                                         Less than once per year
# OpenSource                OSS is, on average, of HIGHER quality than pro...
# Employment                           Not employed, and not looking for work
# Country                                                               Spain
# Student                                                      Yes, full-time
# EdLevel                                  Professional degree (JD, MD, etc.)
# UndergradMajor            Computer science, computer engineering, or sof...
# EduOther                  Taken an online course in programming or softw...
# OrgSize                                                                 NaN
# ...

# %%
df.iloc[[1,-1,8,-8]]
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 1               2  I am a student who is learning to code       No
# 88882       88863                                     NaN      Yes
# 8               9          I am a developer by profession      Yes
# 88875       88182                                     NaN      Yes
#
#                       OpenSourcer  \
# 1         Less than once per year
# 88882     Less than once per year
# 8      Once a month or more often
# 88875  Once a month or more often
#
#                                               OpenSource  \
# 1      The quality of OSS and closed source software ...
# 88882  OSS is, on average, of HIGHER quality than pro...
# 8      The quality of OSS and closed source software ...
# 88875  OSS is, on average, of HIGHER quality than pro...
#
#                                    Employment                 Country  \
# 1          Not employed, but looking for work  Bosnia and Herzegovina
# ...

# %% [markdown]
# # We can also filter columns by passing the index of columns in df.iloc <br>
# It takes the parameters in the format as df.iloc[row_index, column_index]

# %%
df.iloc[[1],-1]
# Out:
# 1    Neither easy nor difficult
# Name: SurveyEase, dtype: object

# %%
df.iloc[[1],[1,-1]]
# Out:
#                                MainBranch                  SurveyEase
# 1  I am a student who is learning to code  Neither easy nor difficult

# %% [markdown]
# # To filter columns in df.loc we must pass the key of the column instead of the index

# %%
df.loc[[1,2], 'Respondent']
# Out:
# 1    2
# 2    3
# Name: Respondent, dtype: int64

# %%
df.loc[[1,2], ['Respondent', 'Hobbyist']]
# Out:
#    Respondent Hobbyist
# 1           2       No
# 2           3      Yes

# %% [markdown]
# # We can perform slicing to retreive rows of records from the data in the row index and column index as well
# End index is inclusive in df.loc because we provide column names instead of index while slicing otherwise it leads to confusion

# %%
df.loc[2:5]
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
# 5           6  I am not primarily a developer, but I write co...      Yes
#
#                   OpenSourcer  \
# 2                       Never
# 3                       Never
# 4  Once a month or more often
# 5                       Never
#
#                                           OpenSource          Employment  \
# 2  The quality of OSS and closed source software ...  Employed full-time
# 3  The quality of OSS and closed source software ...  Employed full-time
# 4  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 5  The quality of OSS and closed source software ...  Employed full-time
#
# ...

# %%
df.loc[2:5, 'Hobbyist':'Country']
# Out:
#   Hobbyist                 OpenSourcer  \
# 2      Yes                       Never
# 3       No                       Never
# 4      Yes  Once a month or more often
# 5      Yes                       Never
#
#                                           OpenSource          Employment  \
# 2  The quality of OSS and closed source software ...  Employed full-time
# 3  The quality of OSS and closed source software ...  Employed full-time
# 4  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 5  The quality of OSS and closed source software ...  Employed full-time
#
#          Country
# 2       Thailand
# 3  United States
# 4        Ukraine
# 5         Canada

# %%
df.iloc[2:5]
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource          Employment  \
# 2  The quality of OSS and closed source software ...  Employed full-time
# 3  The quality of OSS and closed source software ...  Employed full-time
# 4  OSS is, on average, of HIGHER quality than pro...  Employed full-time
#
#          Country Student                                   EdLevel  \
# 2       Thailand      No  Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3  United States      No  Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %% [markdown]
# # In df.iloc we the end index is exclusive while slicing

# %%
df.iloc[2:5, 2:7]
# Out:
#   Hobbyist                 OpenSourcer  \
# 2      Yes                       Never
# 3       No                       Never
# 4      Yes  Once a month or more often
#
#                                           OpenSource          Employment  \
# 2  The quality of OSS and closed source software ...  Employed full-time
# 3  The quality of OSS and closed source software ...  Employed full-time
# 4  OSS is, on average, of HIGHER quality than pro...  Employed full-time
#
#          Country
# 2       Thailand
# 3  United States
# 4        Ukraine

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %% [markdown]
# # We can also set our index using df.set_index or we can define index when creating our dataframe

# %%
df.set_index('Respondent', inplace=True) #inplace True saves the index in our current dataframe

# %%
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
# While creating dataframe
df1 = pd.read_csv('survey_results_public.csv', index_col='Respondent') #index_col is used to set our custom index in the dataframe while creation

# %%
df1
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
del df1

# %% [markdown]
# # This custom index helps us in filterin our data while performing operations in df.loc

# %%
df.loc[2:4, 'Hobbyist':'Country']
# Out:
#            Hobbyist              OpenSourcer  \
# Respondent
# 2                No  Less than once per year
# 3               Yes                    Never
# 4                No                    Never
#
#                                                    OpenSource  \
# Respondent
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# 4           The quality of OSS and closed source software ...
#
#                                     Employment                 Country
# Respondent
# 2           Not employed, but looking for work  Bosnia and Herzegovina
# 3                           Employed full-time                Thailand
# 4                           Employed full-time           United States

# %% [raw]
# We can also reset our index in the dataframe using df.reset_index(inplace=True) we must pass the parameter inplace to save the instance for further use

# %%
df.loc[2:2]
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 2           I am a student who is learning to code       No
#
#                         OpenSourcer  \
# Respondent
# 2           Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 2           The quality of OSS and closed source software ...
#
#                                     Employment                 Country  \
# Respondent
# 2           Not employed, but looking for work  Bosnia and Herzegovina
#
#                    Student                                            EdLevel  \
# Respondent
# 2           Yes, full-time  Secondary school (e.g. American high school, G...
#
#            UndergradMajor                                           EduOther  \
# Respondent
# 2                     NaN  Taken an online course in programming or softw...
#
#            OrgSize                                            DevType  \
# Respondent
# ...

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Respondent              Randomized respondent ID number (not in order ...
# MainBranch              Which of the following options best describes ...
# Hobbyist                                          Do you code as a hobby?
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# Employment              Which of the following best describes your cur...
# Country                         In which country do you currently reside?
# Student                 Are you currently enrolled in a formal, degree...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor          What was your main or most important field of ...
# EduOther                Which of the following types of non-degree edu...
# OrgSize                 Approximately how many people are employed by ...
# ...

# %%
# Sort the index alphabetically
schema_df.sort_index(inplace=True) # ascending=False if we want to sort in the descending order

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Age                     What is your age (in years)? If you prefer not...
# Age1stCode              At what age did you write your first line of c...
# BetterLife              Do you think people born today will have a bet...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BlockchainOrg           How is your organization thinking about or imp...
# CareerSat               Overall, how satisfied are you with your caree...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# CompTotal               What is your current total compensation (salar...
# Containers              How do you use containers (Docker, Open Contai...
# ConvertedComp           Salary converted to annual USD salaries using ...
# ...

# %% [markdown]
# # Filter dataframe

# %%
df['Hobbyist'] == 'Yes' #Returns boolean value we can pass this value in our dataframe to retreive the results
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
#          ...
# 88377     True
# 88601    False
# 88802    False
# 88816    False
# 88863     True
# Name: Hobbyist, Length: 88883, dtype: bool

# %%
filt = (df['Hobbyist'] == 'Yes') #Add brackets for clean code and understanding nothing more
df[filt]
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 3           I am not primarily a developer, but I write co...      Yes
# 5                              I am a developer by profession      Yes
# 6           I am not primarily a developer, but I write co...      Yes
# 8                                 I code primarily as a hobby      Yes
# ...                                                       ...      ...
# 87739                                                     NaN      Yes
# 88182                                                     NaN      Yes
# 88282                                                     NaN      Yes
# 88377                                                     NaN      Yes
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df.loc[filt, 'MainBranch']
# Out:
# Respondent
# 1                   I am a student who is learning to code
# 3        I am not primarily a developer, but I write co...
# 5                           I am a developer by profession
# 6        I am not primarily a developer, but I write co...
# 8                              I code primarily as a hobby
#                                ...
# 87739                                                  NaN
# 88182                                                  NaN
# 88282                                                  NaN
# 88377                                                  NaN
# 88863                                                  NaN
# Name: MainBranch, Length: 71257, dtype: object

# %% [raw]
# Logical Operators to Filter the data
# & - AND operator
# | - OR operator
# ~ - NOT operator

# %%
high_salary = df['ConvertedComp'] > 70000

# %%
df.loc[high_salary, ['Country', 'LanguageWorkedWith', 'ConvertedComp']]
# Out:
#                    Country                                 LanguageWorkedWith  \
# Respondent
# 6                   Canada                                         Java;R;SQL
# 9              New Zealand  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 13           United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 16          United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 22           United States  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...                    ...                                                ...
# 88876        United States  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# 88877        United States  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...
# 88878        United States               HTML/CSS;JavaScript;Scala;TypeScript
# 88879              Finland                   Bash/Shell/PowerShell;C++;Python
# 88882          Netherlands             C#;HTML/CSS;Java;JavaScript;PHP;Python
#
# ...

# %%
countries = ['United States', 'India', 'United Kingdom', 'Germany', 'Canada']
filt = df['Country'].isin(countries)
df.loc[(filt & high_salary), ['Country', 'ConvertedComp']]
# Out:
#                    Country  ConvertedComp
# Respondent
# 6                   Canada       366420.0
# 13           United States        90000.0
# 16          United Kingdom       455352.0
# 22           United States       103000.0
# 26           United States       114000.0
# ...                    ...            ...
# 88873               Canada        72522.0
# 88874        United States      2000000.0
# 88876        United States       180000.0
# 88877        United States      2000000.0
# 88878        United States       130000.0
#
# [16857 rows x 2 columns]

# %%
filt = df['LanguageWorkedWith'].str.contains('Python', na=False)
df.loc[filt, 'LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 84539    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 85738      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 86566      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 87739             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88212                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

# %%
df.rename(columns={'ConvertedComp' : 'Salary'}, inplace=True)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df['Hobbyist'].rename({'Yes': True, 'No': False}, inplace=True)

# %%
# df['Hobbyist'] = df['Hobbyist'].rename({'Yes': True, 'No': False}, inplace=True)
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df.sort_values(by=['Country'], inplace=True)

# %%
df['Country'].head()
# Out:
# Respondent
# 39258    Afghanistan
# 63129    Afghanistan
# 85715    Afghanistan
# 50767    Afghanistan
# 2782     Afghanistan
# Name: Country, dtype: object

# %%
df[['Country', 'Salary']].head()
# Out:
#                 Country     Salary
# Respondent
# 39258       Afghanistan    19152.0
# 63129       Afghanistan  1000000.0
# 85715       Afghanistan        NaN
# 50767       Afghanistan        NaN
# 2782        Afghanistan        NaN

# %%
df.sort_values(by=['Country', 'Salary'], ascending=[True, False], inplace=True)

# %%
df[['Country', 'Salary']].head()
# Out:
#                 Country     Salary
# Respondent
# 63129       Afghanistan  1000000.0
# 50499       Afghanistan   153216.0
# 39258       Afghanistan    19152.0
# 58450       Afghanistan    17556.0
# 7085        Afghanistan    14364.0

# %%
df['Salary'].nlargest(10)
# Out:
# Respondent
# 25983    2000000.0
# 87896    2000000.0
# 22013    2000000.0
# 28243    2000000.0
# 72732    2000000.0
# 78151    2000000.0
# 80200    2000000.0
# 52132    2000000.0
# 75561    2000000.0
# 32250    2000000.0
# Name: Salary, dtype: float64

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq', 'Salary',
#        'WorkWeekHrs', 'WorkPlan', 'WorkChallenge', 'WorkRemote', 'WorkLoc',
#        'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests', 'PurchaseHow',
#        'PurchaseWhat', 'LanguageWorkedWith', 'LanguageDesireNextYear',
#        'DatabaseWorkedWith', 'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df.loc[25833, 'CurrencySymbol':'Salary']
# Out:
# CurrencySymbol    NaN
# CurrencyDesc      NaN
# CompTotal         NaN
# CompFreq          NaN
# Salary            NaN
# Name: 25833, dtype: object

# %%
df.nlargest(10, 'Salary')
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 25983                          I am a developer by profession      Yes
# 87896                          I am a developer by profession      Yes
# 22013                          I am a developer by profession      Yes
# 28243                          I am a developer by profession      Yes
# 72732       I am not primarily a developer, but I write co...       No
# 78151                          I am a developer by profession      Yes
# 80200                          I am a developer by profession      Yes
# 52132                          I am a developer by profession      Yes
# 75561                          I am a developer by profession      Yes
# 32250                          I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 25983                                 Less than once per year
# ...

# %%
df.nsmallest(10, columns=['Salary', 'CompTotal'])
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 40913                          I am a developer by profession      Yes
# 30630                          I am a developer by profession      Yes
# 69049                          I am a developer by profession       No
# 19340       I am not primarily a developer, but I write co...      Yes
# 16214       I am not primarily a developer, but I write co...      Yes
# 29355                          I am a developer by profession      Yes
# 1685                           I am a developer by profession      Yes
# 25298                          I am a developer by profession      Yes
# 50707                          I am a developer by profession      Yes
# 11875                          I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 40913                                 Less than once per year
# ...

# %% [raw]
# mean - Avg of the elements
# median - Middle value in the group of elements
# mode - Most occuring value in the group of elements

# %%
df['Salary'].mean()
# Out:
# 127110.73842323056

# %%
df['Salary'].median()
# Out:
# 57287.0

# %%
df['Salary'].mode()
# Out:
# 0    2000000.0
# Name: Salary, dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# CompTotal      62000.0
# Salary         57287.0
# WorkWeekHrs       40.0
# CodeRevHrs         4.0
# Age               29.0
# dtype: float64

# %%
df.describe()
# Out:
#           CompTotal        Salary   WorkWeekHrs    CodeRevHrs           Age
# count  5.594500e+04  5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11  1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13  2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00  0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04  2.577750e+04     40.000000      2.000000     24.000000
# 50%    6.200000e+04  5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05  1.000000e+05     44.750000      6.000000     35.000000
# max    1.000000e+16  2.000000e+06   4850.000000     99.000000     99.000000

# %%
df['Hobbyist'].count()
# Out:
# 88883

# %%
df['Hobbyist'].value_counts()
# Out:
# Hobbyist
# Yes    71257
# No     17626
# Name: count, dtype: int64

# %%
schema_df.loc['SocialMedia']
# Out:
# QuestionText    What social media site do you use the most?
# Name: SocialMedia, dtype: object

# %%
df['SocialMedia']
# Out:
# Respondent
# 63129    I don't use social media
# 50499                    WhatsApp
# 39258                    Facebook
# 58450                    Facebook
# 7085                    Instagram
#                    ...
# 88062                         NaN
# 88076                         NaN
# 88601                         NaN
# 88802                         NaN
# 88816                         NaN
# Name: SocialMedia, Length: 88883, dtype: object

# %%
df['SocialMedia'].value_counts()
# Out:
# SocialMedia
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: count, dtype: int64

# %%
df['SocialMedia'].value_counts(normalize=True)
# Out:
# SocialMedia
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: proportion, dtype: float64

# %%
df['Country'].value_counts()
# Out:
# Country
# United States                       20949
# India                                9061
# Germany                              5866
# United Kingdom                       5737
# Canada                               3395
#                                     ...
# North Korea                             1
# Niger                                   1
# Saint Vincent and the Grenadines        1
# Chad                                    1
# Brunei Darussalam                       1
# Name: count, Length: 179, dtype: int64

# %%
country_group = df.groupby(['Country'])

# %%
country_group.get_group('India')['Country']
# Out:
# Respondent
# 22013    India
# 28243    India
# 72732    India
# 80923    India
# 78265    India
#          ...
# 79312    India
# 79628    India
# 40151    India
# 76400    India
# 30452    India
# Name: Country, Length: 9061, dtype: object

# %%
filt = df['Country'] == 'India'
df.loc[filt]['SocialMedia'].value_counts()
# Out:
# SocialMedia
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# WeChat 微信                      5
# Hello                          5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: count, dtype: int64

# %%
country_group['SocialMedia'].value_counts()
# Out:
# Country      SocialMedia
# Afghanistan  Facebook                    15
#              YouTube                      9
#              I don't use social media     6
#              WhatsApp                     4
#              Instagram                    1
#                                          ..
# Zimbabwe     Facebook                     3
#              YouTube                      3
#              LinkedIn                     2
#              Instagram                    2
#              Reddit                       1
# Name: count, Length: 1220, dtype: int64

# %%
country_group['SocialMedia'].value_counts().loc['India']
# Out:
# SocialMedia
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# Hello                          5
# WeChat 微信                      5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: count, dtype: int64

# %%
country_group['Salary'].median()
# Out:
# Country
# Afghanistan                               6222.0
# Albania                                  10818.0
# Algeria                                   7878.0
# Andorra                                 160931.0
# Angola                                    7764.0
#                                           ...
# Venezuela, Bolivarian Republic of...      6384.0
# Viet Nam                                 11892.0
# Yemen                                    11940.0
# Zambia                                    5040.0
# Zimbabwe                                 19200.0
# Name: Salary, Length: 179, dtype: float64

# %%
country_group['Salary'].agg(['median', 'mean'])
# Out:
#                                         median           mean
# Country
# Afghanistan                             6222.0  101953.333333
# Albania                                10818.0   21833.700000
# Algeria                                 7878.0   34924.047619
# Andorra                               160931.0  160931.000000
# Angola                                  7764.0    7764.000000
# ...                                        ...            ...
# Venezuela, Bolivarian Republic of...    6384.0   14581.627907
# Viet Nam                               11892.0   17233.436782
# Yemen                                  11940.0   16909.166667
# Zambia                                  5040.0   10075.375000
# Zimbabwe                               19200.0   34046.666667
#
# [179 rows x 2 columns]

# %%
country_group['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
country_grp = country_group['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_grp
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
country_res = df['Country'].value_counts()
country_res
# Out:
# Country
# United States                       20949
# India                                9061
# Germany                              5866
# United Kingdom                       5737
# Canada                               3395
#                                     ...
# North Korea                             1
# Niger                                   1
# Saint Vincent and the Grenadines        1
# Chad                                    1
# Brunei Darussalam                       1
# Name: count, Length: 179, dtype: int64

# %%
python_df = pd.concat([country_res, country_grp], axis='columns', sort=False)

# %%
python_df
# Out:
#                                   count  LanguageWorkedWith
# Country
# United States                     20949               10083
# India                              9061                3105
# Germany                            5866                2451
# United Kingdom                     5737                2384
# Canada                             3395                1558
# ...                                 ...                 ...
# North Korea                           1                   0
# Niger                                 1                   1
# Saint Vincent and the Grenadines      1                   0
# Chad                                  1                   0
# Brunei Darussalam                     1                   0
#
# [179 rows x 2 columns]

# %%
python_df.rename(columns={'count': 'NumRespondent', 'LanguageWorkedWith': 'NumKnowsPython'}, inplace=True)

# %%
python_df['PtcKnowsPython'] = python_df['NumKnowsPython']/python_df['NumRespondent']*100

# %%
python_df
# Out:
#                                   NumRespondent  NumKnowsPython  \
# Country
# United States                             20949           10083
# India                                      9061            3105
# Germany                                    5866            2451
# United Kingdom                             5737            2384
# Canada                                     3395            1558
# ...                                         ...             ...
# North Korea                                   1               0
# Niger                                         1               1
# Saint Vincent and the Grenadines              1               0
# Chad                                          1               0
# Brunei Darussalam                             1               0
#
#                                   PtcKnowsPython
# Country
# United States                          48.131176
# India                                  34.267741
# ...

# %%
python_df.sort_values(by='PtcKnowsPython', ascending=False, inplace=True)

# %%
python_df
# Out:
#                                   NumRespondent  NumKnowsPython  \
# Country
# Sao Tome and Principe                         1               1
# Niger                                         1               1
# Dominica                                      1               1
# Timor-Leste                                   1               1
# Turkmenistan                                  7               6
# ...                                         ...             ...
# Burkina Faso                                  4               0
# Lao People's Democratic Republic              3               0
# Gabon                                         2               0
# Cape Verde                                    3               0
# Brunei Darussalam                             1               0
#
#                                   PtcKnowsPython
# Country
# Sao Tome and Principe                 100.000000
# Niger                                 100.000000
# ...

# %%
python_df.loc[['India', 'United States', 'United Kingdom', 'Pakistan', 'Bangladesh', 'Japan']]
# Out:
#                 NumRespondent  NumKnowsPython  PtcKnowsPython
# Country
# India                    9061            3105       34.267741
# United States           20949           10083       48.131176
# United Kingdom           5737            2384       41.554820
# Pakistan                  923             251       27.193933
# Bangladesh                605             204       33.719008
# Japan                     391             182       46.547315
